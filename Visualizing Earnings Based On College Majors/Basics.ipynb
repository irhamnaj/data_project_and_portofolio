# %% [markdown]
# # Visualizing Earnings Based On College Majors

# %% [markdown]
# in this project i will visualize data  with a dataset on the job outcomes of students who graduated from college between 2010 and 2012 from [fivethirtyeight]('https://github.com/fivethirtyeight/data/tree/master/college-majors') repository

# %%
#import the library
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#read the data and check the data using head and tail function

recent_grads = pd.read_csv('recent-grads.csv')

recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]

cleaned_data_count
# Out:
# 172

# %% [markdown]
# ## Exploring the data using scatter Plot

# %% [markdown]
#  i will exploring column using scatterplot to know the connection between columns

# %%
#sample size x median
ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter',figsize=(5,10))
ax1.set_title('Sample size vs Median')
plt.show()

# %% [markdown]
# from plot we know it is negative linear correlation

# %% [markdown]
# #sample size x unemployment_rate
# ax2 = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', figsize=(5,10))
# ax2.set_title('Sample size vs unemployment rate')
# plt.show()

# %%
ax3 = recent_grads.plot(x='Full_time', y='Median', kind='scatter', figsize=(5,10))
ax3.set_title('Full_time vs Median')
plt.show()

# %% [markdown]
# same as before, negative correlations

# %%
#sharewomen x unemployment_rate
ax4 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', figsize=(5,10))
ax4.set_title('share women vs unemployment rate')
plt.show()

# %% [markdown]
# we cannnot know it's negative or positive because the data have weak correlation

# %%
#men x median
ax5 = recent_grads.plot(x='Men', y='Median', kind='scatter', figsize=(5,10))
ax5.set_title('Men vs Median')
plt.show()

# %%
 #women x median
ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter', figsize=(5,10))
ax6.set_title('women vs Median')

plt.show()

# %% [markdown]
# we got negative correlation in both visualization

# %% [markdown]
# ## popular majors make more money?

# %% [markdown]
# Do students in more popular majors make more money?

# %% [markdown]
# to answer this question, we should know where is popular major and where is unpopular major, after that we can compare it with Median of salary employed

# %% [markdown]
# because for this case we use scatter plot, we will compare the code of major with total using pandas, after that separate it with scatter plot

# %%
#popular major
popular_major = recent_grads[['Major_code','Major','Total','Median']].sort_values('Total', ascending=False).reset_index()[:20]

popular_major
# Out:
#     index  Major_code                                          Major  \
# 0     145        5200                                     PSYCHOLOGY
# 1      76        6203         BUSINESS MANAGEMENT AND ADMINISTRATION
# 2     123        3600                                        BIOLOGY
# 3      57        6200                               GENERAL BUSINESS
# 4      93        1901                                 COMMUNICATIONS
# 5      34        6107                                        NURSING
# 6      77        6206               MARKETING AND MARKETING RESEARCH
# 7      40        6201                                     ACCOUNTING
# 8     137        3301                ENGLISH LANGUAGE AND LITERATURE
# 9      78        5506               POLITICAL SCIENCE AND GOVERNMENT
# 10     35        6207                                        FINANCE
# 11    138        2304                           ELEMENTARY EDUCATION
# 12     94        5301           CRIMINAL JUSTICE AND FIRE PROTECTION
# ...

# %% [markdown]
# for popular major i will using dataset with more than 100000 total which is 20 highest total number

# %%
unpopular_major = recent_grads[['Major_code','Major','Total','Median']].sort_values('Total', ascending=False).reset_index().tail(20)
unpopular_major
# Out:
#      index  Major_code                                              Major  \
# 152      0        2419                              PETROLEUM ENGINEERING
# 153     39        5102  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 154     90        5005                                        GEOSCIENCES
# 155      7        5001                         ASTRONOMY AND ASTROPHYSICS
# 156     48        3607                                       PHARMACOLOGY
# 157    161        1199                          MISCELLANEOUS AGRICULTURE
# 158     72        5000                                  PHYSICAL SCIENCES
# 159     91        5206                                  SOCIAL PSYCHOLOGY
# 160     83        3602                                             BOTANY
# 161      3        2417          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 162     19        3201                                    COURT REPORTING
# 163    172        3501                                    LIBRARY SCIENCE
# ...

# %% [markdown]
# for unpopular major i using 20 with very bottom total

# %% [markdown]
# because we use scatter , so i will using major_code column
# instead major column

# %%
ax7 = popular_major.plot(x='Major_code',y='Median', kind='scatter', figsize=(5,10))

# %%
ax8 = unpopular_major.plot(x='Major_code',y='Median', kind='scatter', figsize=(5,10))

# %% [markdown]
# for that scatter plot we know, popular major not always make more money than unpopular major, we can know it when in scatter plot the popular major, they have median salary max 55000, when unpopular major have data with median higher than 55000.

# %% [markdown]
# let's compare it with other major

# %%
other_major = recent_grads[['Major_code','Major','Total','Median']].sort_values('Total', ascending=False).reset_index()[20:]
ax9 = other_major.plot(x='Major_code',y='Median', kind='scatter', figsize=(5,10))

# %% [markdown]
# same as unpopular major, many of them have salary more than 60000, this can bring us conclusion that popular major non corelated with median, for more analyzing we can scatter plot total with median

# %%
ax9 = recent_grads.plot(x='Total',y='Median', kind='scatter', figsize=(5,10))

# %% [markdown]
# they have negative corelation, when major with total more than 300000 have less median salary than total less than 300000

# %% [markdown]
# because total is the total student_grad, not total student that employed, we can scatter employed with median

# %%
ax9 = recent_grads.plot(x='Employed',y='Median', kind='scatter', figsize=(15,10))

# %% [markdown]
# same as before, negative correlation

# %% [markdown]
# ## Do students that majored in subjects that were majority female make more money?

# %% [markdown]
#  to answer this question we can scatter plot women column with median column

# %%
recent_grads.plot(x='Women',y='Median', kind='scatter', figsize=(10,5))

# %% [markdown]
# it have negative correlation, when major with less women have highest salary

# %% [markdown]
# to more focus we can use women who employed, to use that, we can another column , women_employed

# %%
recent_grads['women_employed'] =recent_grads['Employed'] - recent_grads['Women']
women_grads = recent_grads[recent_grads['women_employed'] > 0]

# %%
women_grads.plot(x='women_employed',y='Median', kind='scatter', figsize=(15,7))

# %% [markdown]
# same as women, negative correlation

# %% [markdown]
# ## Is there any link between the number of full-time employees and median salary?

# %% [markdown]
# to answer this, we should compare employed and median

# %%
recent_grads.plot(x='Full_time',y='Median', kind='scatter', figsize=(15,7))

# %% [markdown]
# have negative correlation, employeed with less full_time have higher median salary

# %% [markdown]
# ## Explore data using histogram

# %% [markdown]
# to start it, let's make histogram from many columns in dataset

# %%
recent_grads['Sample_size'].plot(kind='hist', bins=25, range=(0,5000))

# %%
recent_grads['Median'].plot(kind='hist')

# %%
recent_grads['Employed'].plot(kind='hist')

# %%
recent_grads['Full_time'].plot(kind='hist', range=(0,350000))

# %%
recent_grads['ShareWomen'].plot(kind='hist')

# %%
recent_grads['Unemployment_rate'].plot(kind='hist')

# %%
recent_grads['Men'].plot(kind='hist', range=(0,350000))

# %%
recent_grads['Women'].plot(kind='hist', range=(0,350000))

# %% [markdown]
# ## What percent of majors are predominantly male? Predominantly female?

# %% [markdown]
# to answer precent of predominantly male we will make column with persen male major, after that bar plot that

# %%
#get percent men using calculation
recent_grads['ShareMen'] = 1- recent_grads['ShareWomen']

# %%
recent_grads['ShareMen'].plot(kind='hist', bins=25)

# %% [markdown]
# 0.2 s/d 0.4 was predominantly men

# %% [markdown]
# for women

# %%
recent_grads['ShareWomen'].plot(kind='hist', bins=25)

# %% [markdown]
# 0.6-0.8 predominantly by women

# %% [markdown]
# ## What's the most common median salary range?

# %% [markdown]
#  we can plot the median columns

# %%
recent_grads['Median'].plot(kind='hist', bins=10)

# %% [markdown]
# the most common median salary range is between 30000 and 40000

# %% [markdown]
# ##  plot matrix

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdd48bbef98>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(10,10))
plt.show()

# %% [markdown]
# it can be seen that sample_size have negative correlation with median, when unemplotmen_rate have weak correlation with sample_size and median

# %% [markdown]
# ##  bar plots

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %% [markdown]
# in the first ten recent graduates, astrophysics have the highest percen women when engineering have the samllest percent women

# %%
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')

# %% [markdown]
# in the last ten recent_graduates , communication and early childhood eduation have the highest rate women

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %% [markdown]
# from plot above, i find that engineering have highest enmployment_rate

# %%
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate')

# %% [markdown]
# when the last ten recent graduates,  clinical psychology have the smallest number recent graduates

# %% [markdown]
# ### compare the number of men with the number of women in each category of majors.

# %% [markdown]
# to begin with, let's make many function

# %%
#make dictionary to split the data
category_men ={}
category_women ={}
n_men =0
n_women =0

#using unique to delete duplicate data
major_category = recent_grads['Major_category'].unique()

#loop the every major, in every major sum number of men and women and put it in dictionary
for major in major_category:
    new_data = recent_grads[recent_grads['Major_category']==major]
    n_men = new_data['Men'].sum()
    n_women = new_data['Women'].sum()
    category_men[major] = n_men
    category_women[major] = n_women

# %%
#make new series using new dictionary
major_men_series = pd.Series(category_men)
major_women_series = pd.Series(category_women)

#concat the both of series , become dataframe
men_and_women_major = pd.DataFrame({'total_men': major_men_series, 'total_women': major_women_series})
men_and_women_major
# Out:
#                                      total_men  total_women
# Agriculture & Natural Resources        40357.0      35263.0
# Arts                                  134390.0     222740.0
# Biology & Life Science                184919.0     268943.0
# Business                              667852.0     634524.0
# Communications & Journalism           131921.0     260680.0
# Computers & Mathematics               208725.0      90283.0
# Education                             103526.0     455603.0
# Engineering                           408307.0     129276.0
# Health                                 75517.0     387713.0
# Humanities & Liberal Arts             272846.0     440622.0
# Industrial Arts & Consumer Services   103781.0     126011.0
# Interdisciplinary                       2817.0       9479.0
# Law & Public Policy                    91129.0      87978.0
# Physical Sciences                      95390.0      90089.0
# Psychology & Social Work               98115.0     382892.0
# ...

# %%
#make bar plot
ax = men_and_women_major.plot.bar(figsize=(15,10),rot=90)

# %% [markdown]
# from the data we know that majority women and men have diferent pattern, biggest total women and women has happen in bussines category when smallest total in interdisplinary category.
#
# we also know, that 10 of major_category have total women than men and only six category have more men than women.
#
# many of bar plot have big different too, for example , in engineering category, total of men have big different with total women, when education, social work and health have more women , rather than men, with big different,
#
# for conclution, may be this pattern can happen caused by jobdesk of major category itself and also habit which developing in society,
# for instance, many engineering's job, have outdoor jobdesk, so it will be more men than women

# %% [markdown]
# ### explore the distributions of median salaries and unemployment rate.

# %% [markdown]
# using boxplot to find outliers

# %%
recent_grads.boxplot(column= 'Median')

# %%
recent_grads.boxplot(column= 'Unemployment_rate')

# %% [markdown]
# median and unemployment rate have many outiers

# %% [markdown]
# ### visualize the columns that had dense scatter plots from earlier in the project.

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate','Full_time','ShareWomen','Men','Women']], figsize=(10,10))
plt.show()
